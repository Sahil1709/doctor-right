# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, isnan, when, count, countDistinct

import matplotlib.pyplot as plt
import seaborn as sns
from pyspark.sql.functions import min, max

# %%
spark = SparkSession.builder \
    .appName("EDA on Large Parquet Files") \
    .getOrCreate()

# %%
df1 = spark.read.parquet("sample-data/mx_submitsline.parquet")
df1.printSchema()
# Out:
# root
#  |-- attending_provider_npi: string (nullable = true)
#  |-- billing_provider_address_cbsa_name: string (nullable = true)
#  |-- billing_provider_address_city: string (nullable = true)
#  |-- billing_provider_address_county: string (nullable = true)
#  |-- billing_provider_address_key: string (nullable = true)
#  |-- billing_provider_address_latitude: string (nullable = true)
#  |-- billing_provider_address_longitude: string (nullable = true)
#  |-- billing_provider_address_precision: string (nullable = true)
#  |-- billing_provider_address_region: string (nullable = true)
#  |-- billing_provider_address_state: string (nullable = true)
#  |-- billing_provider_address_street: string (nullable = true)
#  |-- billing_provider_address_zipcode: string (nullable = true)
#  |-- billing_provider_npi: string (nullable = true)
#  |-- claim_all_diagnosis_codes: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- diagnosis_code_set: string (nullable = true)
#  |    |    |-- diagnosis_code: string (nullable = true)
#  |    |    |-- diagnosis_pointer: string (nullable = true)
#  |-- claim_filing_indicator_code: string (nullable = true)
#  |-- claim_filing_indicator_description: string (nullable = true)
#  |-- claim_filing_indicator_pay_type: string (nullable = true)
#  |-- claim_id: string (nullable = true)
#  |-- claim_institutional_or_professional: string (nullable = true)
#  |-- claim_number: string (nullable = true)
#  |-- claim_statement_from_date: date (nullable = true)
#  |-- claim_statement_to_date: date (nullable = true)
#  |-- claim_total_charge_amount: string (nullable = true)
#  |-- clearinghouse_received_date: date (nullable = true)
#  |-- cohort_key: string (nullable = true)
#  |-- cohort_record_id: string (nullable = true)
#  |-- cycle_id: string (nullable = true)
#  |-- diagnosis_code_1: string (nullable = true)
#  |-- diagnosis_code_2: string (nullable = true)
#  |-- diagnosis_code_3: string (nullable = true)
#  |-- diagnosis_code_4: string (nullable = true)
#  |-- diagnosis_code_5: string (nullable = true)
#  |-- diagnosis_code_6: string (nullable = true)
#  |-- diagnosis_code_7: string (nullable = true)
#  |-- diagnosis_code_8: string (nullable = true)
#  |-- drg_code: string (nullable = true)
#  |-- facility_provider_address_cbsa_code: string (nullable = true)
#  |-- facility_provider_address_cbsa_name: string (nullable = true)
#  |-- facility_provider_address_city: string (nullable = true)
#  |-- facility_provider_address_county: string (nullable = true)
#  |-- facility_provider_address_key: string (nullable = true)
#  |-- facility_provider_address_latitude: string (nullable = true)
#  |-- facility_provider_address_longitude: string (nullable = true)
#  |-- facility_provider_address_precision: string (nullable = true)
#  |-- facility_provider_address_region: string (nullable = true)
#  |-- facility_provider_address_state: string (nullable = true)
#  |-- facility_provider_address_street: string (nullable = true)
#  |-- facility_provider_address_suite: string (nullable = true)
#  |-- facility_provider_address_zipcode: string (nullable = true)
#  |-- facility_provider_address_zipcode_type: string (nullable = true)
#  |-- facility_provider_npi: string (nullable = true)
#  |-- inpatient_admission_date: date (nullable = true)
#  |-- inpatient_admission_source_description: string (nullable = true)
#  |-- inpatient_admission_type_description: string (nullable = true)
#  |-- inpatient_admitting_diagnosis_code: string (nullable = true)
#  |-- inpatient_discharge_status_code: string (nullable = true)
#  |-- inpatient_discharge_status_description: string (nullable = true)
#  |-- operating_provider_npi: string (nullable = true)
#  |-- organization_id: string (nullable = true)
#  |-- organization_name: string (nullable = true)
#  |-- organization_npi_type_code: string (nullable = true)
#  |-- organization_sourced_from: string (nullable = true)
#  |-- organization_sourced_npi: string (nullable = true)
#  |-- organization_taxonomy_classification: string (nullable = true)
#  |-- organization_taxonomy_code: string (nullable = true)
#  |-- organization_taxonomy_description: string (nullable = true)
#  |-- organization_taxonomy_group: string (nullable = true)
#  |-- patient_birth_year: integer (nullable = true)
#  |-- patient_gender: string (nullable = true)
#  |-- patient_id: string (nullable = true)
#  |-- patient_location_preferred_latitude: string (nullable = true)
#  |-- patient_location_preferred_longitude: string (nullable = true)
#  |-- patient_location_preferred_type: integer (nullable = true)
#  |-- patient_location_preferred_zipcode: string (nullable = true)
#  |-- patient_location_residential_region: string (nullable = true)
#  |-- patient_location_residential_state: string (nullable = true)
#  |-- patient_location_residential_zip3: string (nullable = true)
#  |-- patient_relationship_to_subscriber_description: string (nullable = true)
#  |-- primary_payer_id_raw_source_value: string (nullable = true)
#  |-- primary_payer_name: string (nullable = true)
#  |-- primary_payer_name_raw_source_value: string (nullable = true)
#  |-- primary_payer_pay_type: string (nullable = true)
#  |-- primary_payer_pay_type_raw_source_value: string (nullable = true)
#  |-- primary_payer_plan_type: string (nullable = true)
#  |-- primary_payer_state_raw_source_value: string (nullable = true)
#  |-- principal_diagnosis_body_part: string (nullable = true)
#  |-- principal_diagnosis_category: string (nullable = true)
#  |-- principal_diagnosis_classification: string (nullable = true)
#  |-- principal_diagnosis_code_set: string (nullable = true)
#  |-- principal_diagnosis_description: string (nullable = true)
#  |-- principal_procedure_category: string (nullable = true)
#  |-- principal_procedure_code: string (nullable = true)
#  |-- principal_procedure_code_set: string (nullable = true)
#  |-- principal_procedure_description: string (nullable = true)
#  |-- referring_provider_current_practice_organization_id: string (nullable = true)
#  |-- referring_provider_current_practice_organization_name: string (nullable = true)
#  |-- referring_provider_name: string (nullable = true)
#  |-- referring_provider_npi: string (nullable = true)
#  |-- referring_provider_npi_type_code: string (nullable = true)
#  |-- referring_provider_taxonomy_classification: string (nullable = true)
#  |-- referring_provider_taxonomy_code: string (nullable = true)
#  |-- referring_provider_taxonomy_description: string (nullable = true)
#  |-- referring_provider_taxonomy_group: string (nullable = true)
#  |-- rendering_provider_current_practice_organization_id: string (nullable = true)
#  |-- rendering_provider_current_practice_organization_name: string (nullable = true)
#  |-- rendering_provider_name: string (nullable = true)
#  |-- rendering_provider_npi: string (nullable = true)
#  |-- rendering_provider_npi_type_code: string (nullable = true)
#  |-- rendering_provider_taxonomy_classification: string (nullable = true)
#  |-- rendering_provider_taxonomy_code: string (nullable = true)
#  |-- rendering_provider_taxonomy_description: string (nullable = true)
#  |-- rendering_provider_taxonomy_group: string (nullable = true)
#  |-- secondary_payer_claim_filing_indicator_code: string (nullable = true)
#  |-- secondary_payer_id: string (nullable = true)
#  |-- secondary_payer_name: string (nullable = true)
#  |-- secondary_payer_name_raw_source_value: string (nullable = true)
#  |-- secondary_payer_pay_type: string (nullable = true)
#  |-- secondary_payer_plan_type: string (nullable = true)
#  |-- secondary_payer_state: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- source_increment_id: string (nullable = true)
#  |-- type_of_bill_classification_description: string (nullable = true)
#  |-- type_of_bill_code: string (nullable = true)
#  |-- type_of_bill_facility_description: string (nullable = true)
#  |-- type_of_bill_frequency_description: string (nullable = true)
#  |-- vendorname: string (nullable = true)
#  |-- line_level_number: string (nullable = true)
#  |-- line_level_emergency_indicator: string (nullable = true)
#  |-- line_level_charge_amount: string (nullable = true)
#  |-- line_level_drug_ndc: string (nullable = true)
#  |-- line_level_drug_dosage_route: string (nullable = true)
#  |-- line_level_drug_name: string (nullable = true)
#  |-- line_level_drug_packaging_information: string (nullable = true)
#  |-- line_level_drug_product_type: string (nullable = true)
#  |-- line_level_drug_brand_name: string (nullable = true)
#  |-- line_level_place_of_service_description: string (nullable = true)
#  |-- line_level_place_of_service_code: string (nullable = true)
#  |-- line_level_procedure_code: string (nullable = true)
#  |-- line_level_procedure_code_set: string (nullable = true)
#  |-- line_level_procedure_description: string (nullable = true)
#  |-- line_level_procedure_modifier_1: string (nullable = true)
#  |-- line_level_procedure_modifier_2: string (nullable = true)
#  |-- line_level_procedure_modifier_3: string (nullable = true)
#  |-- line_level_procedure_modifier_4: string (nullable = true)
#  |-- line_level_procedure_category: string (nullable = true)
#  |-- line_level_revenue_code: string (nullable = true)
#  |-- line_level_revenue_description: string (nullable = true)
#  |-- line_level_from_date: date (nullable = true)
#  |-- line_level_to_date: date (nullable = true)
#  |-- line_level_units_billed: string (nullable = true)

# %%
df1.show(5)
# Out:
# +----------------------+----------------------------------+-----------------------------+-------------------------------+----------------------------+---------------------------------+----------------------------------+----------------------------------+-------------------------------+------------------------------+-------------------------------+--------------------------------+--------------------+-------------------------+---------------------------+----------------------------------+-------------------------------+--------------------+-----------------------------------+--------------------+-------------------------+-----------------------+-------------------------+---------------------------+--------------------+--------------------+-------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+--------+-----------------------------------+-----------------------------------+------------------------------+--------------------------------+-----------------------------+----------------------------------+-----------------------------------+-----------------------------------+--------------------------------+-------------------------------+--------------------------------+-------------------------------+---------------------------------+--------------------------------------+---------------------+------------------------+--------------------------------------+------------------------------------+----------------------------------+-------------------------------+--------------------------------------+----------------------+--------------------+--------------------+--------------------------+-------------------------+------------------------+------------------------------------+--------------------------+---------------------------------+---------------------------+------------------+--------------+--------------------+-----------------------------------+------------------------------------+-------------------------------+----------------------------------+-----------------------------------+----------------------------------+---------------------------------+----------------------------------------------+---------------------------------+--------------------+-----------------------------------+----------------------+---------------------------------------+-----------------------+------------------------------------+-----------------------------+----------------------------+----------------------------------+----------------------------+-------------------------------+----------------------------+------------------------+----------------------------+-------------------------------+---------------------------------------------------+-----------------------------------------------------+-----------------------+----------------------+--------------------------------+------------------------------------------+--------------------------------+---------------------------------------+---------------------------------+---------------------------------------------------+-----------------------------------------------------+-----------------------+----------------------+--------------------------------+------------------------------------------+--------------------------------+---------------------------------------+---------------------------------+-------------------------------------------+------------------+--------------------+-------------------------------------+------------------------+-------------------------+---------------------+---------+-------------------+---------------------------------------+-----------------+---------------------------------+----------------------------------+----------+-----------------+------------------------------+------------------------+-------------------+----------------------------+--------------------+-------------------------------------+----------------------------+--------------------------+-------------- ...
# |attending_provider_npi|billing_provider_address_cbsa_name|billing_provider_address_city|billing_provider_address_county|billing_provider_address_key|billing_provider_address_latitude|billing_provider_address_longitude|billing_provider_address_precision|billing_provider_address_region|billing_provider_address_state|billing_provider_address_street|billing_provider_address_zipcode|billing_provider_npi|claim_all_diagnosis_codes|claim_filing_indicator_code|claim_filing_indicator_description|claim_filing_indicator_pay_type|            claim_id|claim_institutional_or_professional|        claim_number|claim_statement_from_date|claim_statement_to_date|claim_total_charge_amount|clearinghouse_received_date|          cohort_key|    cohort_record_id|     cycle_id|diagnosis_code_1|diagnosis_code_2|diagnosis_code_3|diagnosis_code_4|diagnosis_code_5|diagnosis_code_6|diagnosis_code_7|diagnosis_code_8|drg_code|facility_provider_address_cbsa_code|facility_provider_address_cbsa_name|facility_provider_address_city|facility_provider_address_county|facility_provider_address_key|facility_provider_address_latitude|facility_provider_address_longitude|facility_provider_address_precision|facility_provider_address_region|facility_provider_address_state|facility_provider_address_street|facility_provider_address_suite|facility_provider_address_zipcode|facility_provider_address_zipcode_type|facility_provider_npi|inpatient_admission_date|inpatient_admission_source_description|inpatient_admission_type_description|inpatient_admitting_diagnosis_code|inpatient_discharge_status_code|inpatient_discharge_status_description|operating_provider_npi|     organization_id|   organization_name|organization_npi_type_code|organization_sourced_from|organization_sourced_npi|organization_taxonomy_classification|organization_taxonomy_code|organization_taxonomy_description|organization_taxonomy_group|patient_birth_year|patient_gender|          patient_id|patient_location_preferred_latitude|patient_location_preferred_longitude|patient_location_preferred_type|patient_location_preferred_zipcode|patient_location_residential_region|patient_location_residential_state|patient_location_residential_zip3|patient_relationship_to_subscriber_description|primary_payer_id_raw_source_value|  primary_payer_name|primary_payer_name_raw_source_value|primary_payer_pay_type|primary_payer_pay_type_raw_source_value|primary_payer_plan_type|primary_payer_state_raw_source_value|principal_diagnosis_body_part|principal_diagnosis_category|principal_diagnosis_classification|principal_diagnosis_code_set|principal_diagnosis_description|principal_procedure_category|principal_procedure_code|principal_procedure_code_set|principal_procedure_description|referring_provider_current_practice_organization_id|referring_provider_current_practice_organization_name|referring_provider_name|referring_provider_npi|referring_provider_npi_type_code|referring_provider_taxonomy_classification|referring_provider_taxonomy_code|referring_provider_taxonomy_description|referring_provider_taxonomy_group|rendering_provider_current_practice_organization_id|rendering_provider_current_practice_organization_name|rendering_provider_name|rendering_provider_npi|rendering_provider_npi_type_code|rendering_provider_taxonomy_classification|rendering_provider_taxonomy_code|rendering_provider_taxonomy_description|rendering_provider_taxonomy_group|secondary_payer_claim_filing_indicator_code|secondary_payer_id|secondary_payer_name|secondary_payer_name_raw_source_value|secondary_payer_pay_type|secondary_payer_plan_type|secondary_payer_state|source_id|source_increment_id|type_of_bill_classification_description|type_of_bill_code|type_of_bill_facility_description|type_of_bill_frequency_description|vendorname|line_level_number|line_level_emergency_indicator|line_level_charge_amount|line_level_drug_ndc|line_level_drug_dosage_route|line_level_drug_name|line_level_drug_packaging_information|line_level_drug_product_type|line_level_drug_brand_name|line_level_pla ...
# +----------------------+----------------------------------+-----------------------------+-------------------------------+----------------------------+---------------------------------+----------------------------------+----------------------------------+-------------------------------+------------------------------+-------------------------------+--------------------------------+--------------------+-------------------------+---------------------------+----------------------------------+-------------------------------+--------------------+-----------------------------------+--------------------+-------------------------+-----------------------+-------------------------+---------------------------+--------------------+--------------------+-------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+--------+-----------------------------------+-----------------------------------+------------------------------+--------------------------------+-----------------------------+----------------------------------+-----------------------------------+-----------------------------------+--------------------------------+-------------------------------+--------------------------------+-------------------------------+---------------------------------+--------------------------------------+---------------------+------------------------+--------------------------------------+------------------------------------+----------------------------------+-------------------------------+--------------------------------------+----------------------+--------------------+--------------------+--------------------------+-------------------------+------------------------+------------------------------------+--------------------------+---------------------------------+---------------------------+------------------+--------------+--------------------+-----------------------------------+------------------------------------+-------------------------------+----------------------------------+-----------------------------------+----------------------------------+---------------------------------+----------------------------------------------+---------------------------------+--------------------+-----------------------------------+----------------------+---------------------------------------+-----------------------+------------------------------------+-----------------------------+----------------------------+----------------------------------+----------------------------+-------------------------------+----------------------------+------------------------+----------------------------+-------------------------------+---------------------------------------------------+-----------------------------------------------------+-----------------------+----------------------+--------------------------------+------------------------------------------+--------------------------------+---------------------------------------+---------------------------------+---------------------------------------------------+-----------------------------------------------------+-----------------------+----------------------+--------------------------------+------------------------------------------+--------------------------------+---------------------------------------+---------------------------------+-------------------------------------------+------------------+--------------------+-------------------------------------+------------------------+-------------------------+---------------------+---------+-------------------+---------------------------------------+-----------------+---------------------------------+----------------------------------+----------+-----------------+------------------------------+------------------------+-------------------+----------------------------+--------------------+-------------------------------------+----------------------------+--------------------------+-------------- ...
# |                  NULL|              NEW YORK-NEWARK-J...|                East Setauket|                        Suffolk|        210NBELLEMEADAVEE...|                          40.8978|                        -73.089386|                           Rooftop|                      Northeast|                            NY|           210 N Belle Mead Ave|                           11733|          1922364181|     [{ICD10, R112, 1}...|                         CI|              Commercial Insura...|                     Commercial|b2a95a87a0215a044...|                                  P|b2a95a87a0215a044...|               2022-12-28|             2022-12-28|                    30.00|                 2023-01-09|f74909ace68e51891...|28c997770875e746e...|full_20240611|            R112|            R197|            NULL|            NULL|            NULL|            NULL|            NULL|            NULL|    NULL|                               NULL|                               NULL|                          NULL|                            NULL|                         NULL|                              NULL|                               NULL|                               NULL|                            NULL|                           NULL|                            NULL|                           NULL|                             NULL|                                  NULL|           1063831428|                    NULL|                                  NULL|                                NULL|                              NULL|                           NULL|                                  NULL|                  NULL|ORG83657390E28064...|THREE VILLAGE CAR...|                         2|                  Billing|              1922364181|                   Internal Medicine|                207RC0000X|             Internal Medicine...|       Allopathic & Oste...|              1979|             F|d84021f90cfce8287...|                          40.907303|                          -73.154626|                              1|                             11780|                          Northeast|                                NY|                              117|                                        Spouse|                            87726|UNITED HEALTHCARE...|                  UNITED HEALTHCARE|            Commercial|                                     CI|                   NULL|                                NULL|                         NULL|        Symptoms, signs, ...|                              NULL|                       ICD10|           NAUSEA WITH VOMIT...|                        NULL|                   93010|                         CPT|           INTERPRETATION AN...|                               ORGCAEF5AF5E5E50F...|                                 THREE VILLAGE CAR...|          SHARMA, MOHIT|            1063831428|                               1|                         Internal Medicine|                      207RC0000X|                   Internal Medicine...|             Allopathic & Oste...|                               ORGCAEF5AF5E5E50F...|                                 THREE VILLAGE CAR...|          SHARMA, MOHIT|            1063831428|                               1|                         Internal Medicine|                      207RC0000X|                   Internal Medicine...|             Allopathic & Oste...|                                       NULL|              NULL|                NULL|                                 NULL|                    NULL|                     NULL|                 NULL|       C1|           20230118|                                   NULL|             NULL|                             NULL|              Admit Through Dis...|      cyan|                1|                             Y|                   30.00|               NULL|                        NULL|                NULL|                                 NULL|                        NULL|                      NULL|               ...
# |            1811950736|                              NULL|                         NULL|                           NULL|                        NULL|                             NULL|                              NULL|                              NULL|                           NULL|                          NULL|                           NULL|                            NULL|                NULL|     [{ICD10, E1165, 0...|                          F|              Commercial Insura...|                     Commercial|d696e3913b43c3c20...|                                  I|d696e3913b43c3c20...|               2018-10-18|             2018-10-18|                   167.00|                 2018-10-24|f74909ace68e51891...|809864a8c09eaab15...|full_20240611|           E1165|            NULL|            NULL|            NULL|            NULL|            NULL|            NULL|            NULL|    NULL|                               NULL|                               NULL|                          NULL|                            NULL|                         NULL|                              NULL|                               NULL|                               NULL|                            NULL|                           NULL|                            NULL|                           NULL|                             NULL|                                  NULL|           1811950736|                    NULL|                       Clinic Referral|                            Elective|                              NULL|                             01|                  Discharged to hom...|                  NULL|                NULL|                NULL|                         1|                Attending|              1811950736|                     Family Medicine|                207Q00000X|                  Family Medicine|       Allopathic & Oste...|              1971|             U|b5ee1620c24f451eb...|                          42.805156|                          -85.652962|                              1|                             49315|                            Midwest|                                MI|                              493|                                          Self|                             3550|UNITED HEALTHCARE...|                  UNITED HEALTHCARE|            Commercial|                                      F|                   NULL|                                NULL|                         NULL|        Endocrine, nutrit...|                              NULL|                       ICD10|           TYPE 2 DIABETES M...|                        NULL|                   G0109|                        HCPC|           DIABETES OUTPATIE...|                                               NULL|                                                 NULL|                   NULL|                  NULL|                            NULL|                                      NULL|                            NULL|                                   NULL|                             NULL|                               ORGA782DE73762FCA...|                                 METRO HEALTH HOSP...|       BESSERT, LINDA M|            1811950736|                               1|                           Family Medicine|                      207Q00000X|                        Family Medicine|             Allopathic & Oste...|                                       NULL|              NULL|                NULL|                                 NULL|                    NULL|                     NULL|                 NULL|       C4|           20210630|                             Outpatient|              131|                         Hospital|              Admit Through Dis...|      cyan|                1|                          NULL|                  167.00|               NULL|                        NULL|                NULL|                                 NULL|                        NULL|                      NULL|               ...
# |summary|        claim_number|          cohort_key|    cohort_record_id|attending_provider_npi|billing_provider_address_cbsa_name|billing_provider_address_city|billing_provider_address_county|billing_provider_address_key|billing_provider_address_latitude|billing_provider_address_longitude|billing_provider_address_precision|billing_provider_address_region|billing_provider_address_state|billing_provider_address_street|billing_provider_address_zipcode|billing_provider_npi|claim_filing_indicator_code|claim_filing_indicator_description|claim_filing_indicator_pay_type|            claim_id|claim_institutional_or_professional|claim_total_charge_amount| diagnosis_code_1|  diagnosis_code_2| diagnosis_code_3| diagnosis_code_4| diagnosis_code_5|  diagnosis_code_6|  diagnosis_code_7|  diagnosis_code_8|          drg_code|facility_provider_address_cbsa_code|facility_provider_address_cbsa_name|facility_provider_address_city|facility_provider_address_county|facility_provider_address_key|facility_provider_address_latitude|facility_provider_address_longitude|facility_provider_address_precision|facility_provider_address_region|facility_provider_address_state|facility_provider_address_street|facility_provider_address_suite|facility_provider_address_zipcode|facility_provider_address_zipcode_type|facility_provider_npi|inpatient_admission_source_description|inpatient_admission_type_description|inpatient_admitting_diagnosis_code|inpatient_discharge_status_code|inpatient_discharge_status_description|operating_provider_npi|     organization_id|   organization_name|organization_npi_type_code|organization_sourced_from|organization_sourced_npi|organization_taxonomy_classification|organization_taxonomy_code|organization_taxonomy_description|organization_taxonomy_group|patient_location_residential_region|patient_location_residential_state|patient_location_residential_zip3|patient_relationship_to_subscriber_description|primary_payer_id_raw_source_value|  primary_payer_name|primary_payer_name_raw_source_value|primary_payer_pay_type|primary_payer_pay_type_raw_source_value|primary_payer_plan_type|primary_payer_state_raw_source_value|principal_diagnosis_body_part|principal_diagnosis_category|principal_diagnosis_classification|principal_diagnosis_code_set|principal_diagnosis_description|principal_procedure_category|principal_procedure_code|principal_procedure_code_set|principal_procedure_description|referring_provider_current_practice_organization_id|referring_provider_current_practice_organization_name|referring_provider_name|referring_provider_npi|referring_provider_npi_type_code|referring_provider_taxonomy_classification|referring_provider_taxonomy_code|referring_provider_taxonomy_description|referring_provider_taxonomy_group|rendering_provider_current_practice_organization_id|rendering_provider_current_practice_organization_name|rendering_provider_name|rendering_provider_npi|rendering_provider_npi_type_code|rendering_provider_taxonomy_classification|rendering_provider_taxonomy_code|rendering_provider_taxonomy_description|rendering_provider_taxonomy_group|secondary_payer_claim_filing_indicator_code|  secondary_payer_id|secondary_payer_name|secondary_payer_name_raw_source_value|secondary_payer_pay_type|secondary_payer_plan_type|secondary_payer_state|source_id| source_increment_id|type_of_bill_classification_description| type_of_bill_code|type_of_bill_facility_description|type_of_bill_frequency_description|vendorname|      cycle_id|patient_birth_year|patient_gender|          patient_id|patient_location_preferred_latitude|patient_location_preferred_longitude|patient_location_preferred_zipcode|patient_location_preferred_type|
# +-------+--------------------+--------------------+--------------------+----------------------+----------------------------------+-----------------------------+-------------------------------+----------------------------+---------------------------------+----------------------------------+----------------------------------+-------------------------------+------------------------------+-------------------------------+--------------------------------+--------------------+---------------------------+----------------------------------+-------------------------------+--------------------+-----------------------------------+-------------------------+-----------------+------------------+-----------------+-----------------+-----------------+------------------+------------------+------------------
float_and_timestamp_cols = [col_name for col_name, dtype in df1.dtypes if dtype in ['float', 'int', 'date']]

# Describe the float and timestamp columns
df1.select(float_and_timestamp_cols).describe().show()
# Out:
# [Stage 5:=========================================>               (16 + 6) / 22]
# +-------+------------------+-------------------------------+
# |summary|patient_birth_year|patient_location_preferred_type|
# +-------+------------------+-------------------------------+
# |  count|          15337531|                       13767756|
# |   mean|1983.8176939952068|              1.146122795900799|
# | stddev| 352.8397439976159|            0.35322929306822703|
# |    min|              1931|                              1|
# |    max|              9999|                              2|
# +-------+------------------+-------------------------------+

# %%
float_and_timestamp_cols
# Out:
# ['claim_statement_from_date',
#  'claim_statement_to_date',
#  'clearinghouse_received_date',
#  'inpatient_admission_date',
#  'patient_birth_year',
#  'patient_location_preferred_type',
#  'line_level_from_date',
#  'line_level_to_date']

# %%
from pyspark.sql import Row

def date_describe(date_columns):
    results = []
    for c in date_columns:
        result = df1.select(
            count(c).alias("total_rows"),
            countDistinct(c).alias("distinct_dates"),
            count(col(c).isNull()).alias("null_dates"),
            min(c).alias("min_date"),
            max(c).alias("max_date")
        ).collect()[0]
        results.append(Row(column=c, **result.asDict()))
    
    return spark.createDataFrame(results)

# Filter out non-date columns
date_columns = [col_name for col_name, dtype in df1.dtypes if dtype == 'date']
date_describe(date_columns).show()
# Out:
# +--------------------+----------+--------------+----------+----------+----------+
# |              column|total_rows|distinct_dates|null_dates|  min_date|  max_date|
# +--------------------+----------+--------------+----------+----------+----------+
# |claim_statement_f...|  15482079|          3548|  15501334|2013-11-13|2024-09-05|
# |claim_statement_t...|  15482079|          3548|  15501334|2013-11-13|2024-09-05|
# |clearinghouse_rec...|  15501334|          3537|  15501334|2015-01-01|2024-09-06|
# |inpatient_admissi...|   1984190|          3878|  15501334|1920-08-02|2024-09-03|
# |line_level_from_date|  15401550|          3548|  15501334|2013-11-13|2024-09-05|
# |  line_level_to_date|  15401544|          3552|  15501334|2013-11-13|2024-09-26|
# +--------------------+----------+--------------+----------+----------+----------+

# %%
print(f"Number of rows: {df1.count()}")
print(f"Number of columns: {len(df1.columns)}")
# Out:
# [Stage 2:=================================>                       (13 + 8) / 22]
# Number of rows: 15501334
# Number of columns: 150

# %%
df1.groupBy("patient_location_preferred_type").count().orderBy("count", ascending=False).show()
# Out:
# [Stage 5:=========================================>               (16 + 6) / 22]
# +-------------------------------+--------+
# |patient_location_preferred_type|   count|
# +-------------------------------+--------+
# |                              1|11755973|
# |                              2| 2011783|
# |                           NULL| 1733578|
# +-------------------------------+--------+

# %%
greater_null_percentages = [
    'attending_provider_npi', 'claim_all_diagnosis_codes', 'drg_code', 
    'inpatient_admitting_diagnosis_code', 'operating_provider_npi', 'principal_diagnosis_classification', 
    'line_level_drug_packaging_information'
]


def is_numeric_type(df, col_name):
    return dict(df.dtypes)[col_name] in ['int', 'bigint', 'float', 'double', 'decimal']

exprs = []
for col_name in greater_null_percentages:
    if is_numeric_type(df1, col_name):
        exprs.append(count(when(col(col_name).isNull() | isnan(col(col_name)), col_name)).alias(col_name))
    else:
        exprs.append(count(when(col(col_name).isNull(), col_name)).alias(col_name))

null_counts = df1.select(exprs)

null_counts.show()
# Out:
# [Stage 8:=========================================>               (16 + 6) / 22]
# +----------------------+-------------------------+--------+----------------------------------+----------------------+----------------------------------+-------------------------------------+
# |attending_provider_npi|claim_all_diagnosis_codes|drg_code|inpatient_admitting_diagnosis_code|operating_provider_npi|principal_diagnosis_classification|line_level_drug_packaging_information|
# +----------------------+-------------------------+--------+----------------------------------+----------------------+----------------------------------+-------------------------------------+
# |              13969235|                    21850|15220257|                          14961229|              14940599|                          15498021|                             15088418|
# +----------------------+-------------------------+--------+----------------------------------+----------------------+----------------------------------+-------------------------------------+

# %%
# Calculate the total number of rows in the dataframe
total_rows = df1.count()

# Calculate the percentage of null counts for each column
null_percentages = null_counts.select(
    [(col(c) / total_rows * 100).alias(c) for c in null_counts.columns]
)

null_percentages.show()
# Out:
# [Stage 14:=============================================>          (18 + 4) / 22]
# +----------------------+-------------------------+-----------------+----------------------------------+----------------------+----------------------------------+-------------------------------------+
# |attending_provider_npi|claim_all_diagnosis_codes|         drg_code|inpatient_admitting_diagnosis_code|operating_provider_npi|principal_diagnosis_classification|line_level_drug_packaging_information|
# +----------------------+-------------------------+-----------------+----------------------------------+----------------------+----------------------------------+-------------------------------------+
# |     90.11634095491394|      0.14095561065905685|98.18675605596266|                  96.5157514830659|     96.38266616279606|                 99.97862764585294|                    97.33625506037093|
# +----------------------+-------------------------+-----------------+----------------------------------+----------------------+----------------------------------+-------------------------------------+

# %%
df1.dtypes
# Out:
# [('attending_provider_npi', 'string'),
#  ('billing_provider_address_cbsa_name', 'string'),
#  ('billing_provider_address_city', 'string'),
#  ('billing_provider_address_county', 'string'),
#  ('billing_provider_address_key', 'string'),
#  ('billing_provider_address_latitude', 'string'),
#  ('billing_provider_address_longitude', 'string'),
#  ('billing_provider_address_precision', 'string'),
#  ('billing_provider_address_region', 'string'),
#  ('billing_provider_address_state', 'string'),
#  ('billing_provider_address_street', 'string'),
#  ('billing_provider_address_zipcode', 'string'),
#  ('billing_provider_npi', 'string'),
#  ('claim_all_diagnosis_codes',
#   'array<struct<diagnosis_code_set:string,diagnosis_code:string,diagnosis_pointer:string>>'),
#  ('claim_filing_indicator_code', 'string'),
#  ('claim_filing_indicator_description', 'string'),
#  ('claim_filing_indicator_pay_type', 'string'),
#  ('claim_id', 'string'),
#  ('claim_institutional_or_professional', 'string'),
#  ('claim_number', 'string'),
#  ('claim_statement_from_date', 'date'),
#  ('claim_statement_to_date', 'date'),
#  ('claim_total_charge_amount', 'string'),
#  ('clearinghouse_received_date', 'date'),
#  ('cohort_key', 'string'),
#  ('cohort_record_id', 'string'),
#  ('cycle_id', 'string'),
#  ('diagnosis_code_1', 'string'),
#  ('diagnosis_code_2', 'string'),
#  ('diagnosis_code_3', 'string'),
#  ('diagnosis_code_4', 'string'),
#  ('diagnosis_code_5', 'string'),
#  ('diagnosis_code_6', 'string'),
#  ('diagnosis_code_7', 'string'),
#  ('diagnosis_code_8', 'string'),
#  ('drg_code', 'string'),
#  ('facility_provider_address_cbsa_code', 'string'),
#  ('facility_provider_address_cbsa_name', 'string'),
#  ('facility_provider_address_city', 'string'),
#  ('facility_provider_address_county', 'string'),
#  ('facility_provider_address_key', 'string'),
#  ('facility_provider_address_latitude', 'string'),
#  ('facility_provider_address_longitude', 'string'),
#  ('facility_provider_address_precision', 'string'),
#  ('facility_provider_address_region', 'string'),
#  ('facility_provider_address_state', 'string'),
#  ('facility_provider_address_street', 'string'),
#  ('facility_provider_address_suite', 'string'),
#  ('facility_provider_address_zipcode', 'string'),
#  ('facility_provider_address_zipcode_type', 'string'),
#  ('facility_provider_npi', 'string'),
#  ('inpatient_admission_date', 'date'),
#  ('inpatient_admission_source_description', 'string'),
#  ('inpatient_admission_type_description', 'string'),
#  ('inpatient_admitting_diagnosis_code', 'string'),
#  ('inpatient_discharge_status_code', 'string'),
#  ('inpatient_discharge_status_description', 'string'),
#  ('operating_provider_npi', 'string'),
#  ('organization_id', 'string'),
#  ('organization_name', 'string'),
#  ('organization_npi_type_code', 'string'),
#  ('organization_sourced_from', 'string'),
#  ('organization_sourced_npi', 'string'),
#  ('organization_taxonomy_classification', 'string'),
#  ('organization_taxonomy_code', 'string'),
#  ('organization_taxonomy_description', 'string'),
#  ('organization_taxonomy_group', 'string'),
#  ('patient_birth_year', 'int'),
#  ('patient_gender', 'string'),
#  ('patient_id', 'string'),
#  ('patient_location_preferred_latitude', 'string'),
#  ('patient_location_preferred_longitude', 'string'),
#  ('patient_location_preferred_type', 'int'),
#  ('patient_location_preferred_zipcode', 'string'),
#  ('patient_location_residential_region', 'string'),
#  ('patient_location_residential_state', 'string'),
#  ('patient_location_residential_zip3', 'string'),
#  ('patient_relationship_to_subscriber_description', 'string'),
#  ('primary_payer_id_raw_source_value', 'string'),
#  ('primary_payer_name', 'string'),
#  ('primary_payer_name_raw_source_value', 'string'),
#  ('primary_payer_pay_type', 'string'),
#  ('primary_payer_pay_type_raw_source_value', 'string'),
#  ('primary_payer_plan_type', 'string'),
#  ('primary_payer_state_raw_source_value', 'string'),
#  ('principal_diagnosis_body_part', 'string'),
#  ('principal_diagnosis_category', 'string'),
#  ('principal_diagnosis_classification', 'string'),
#  ('principal_diagnosis_code_set', 'string'),
#  ('principal_diagnosis_description', 'string'),
#  ('principal_procedure_category', 'string'),
#  ('principal_procedure_code', 'string'),
#  ('principal_procedure_code_set', 'string'),
#  ('principal_procedure_description', 'string'),
#  ('referring_provider_current_practice_organization_id', 'string'),
#  ('referring_provider_current_practice_organization_name', 'string'),
#  ('referring_provider_name', 'string'),
#  ('referring_provider_npi', 'string'),
#  ('referring_provider_npi_type_code', 'string'),
#  ('referring_provider_taxonomy_classification', 'string'),
#  ('referring_provider_taxonomy_code', 'string'),
#  ('referring_provider_taxonomy_description', 'string'),
#  ('referring_provider_taxonomy_group', 'string'),
#  ('rendering_provider_current_practice_organization_id', 'string'),
#  ('rendering_provider_current_practice_organization_name', 'string'),
#  ('rendering_provider_name', 'string'),
#  ('rendering_provider_npi', 'string'),
#  ('rendering_provider_npi_type_code', 'string'),
#  ('rendering_provider_taxonomy_classification', 'string'),
#  ('rendering_provider_taxonomy_code', 'string'),
#  ('rendering_provider_taxonomy_description', 'string'),
#  ('rendering_provider_taxonomy_group', 'string'),
#  ('secondary_payer_claim_filing_indicator_code', 'string'),
#  ('secondary_payer_id', 'string'),
#  ('secondary_payer_name', 'string'),
#  ('secondary_payer_name_raw_source_value', 'string'),
#  ('secondary_payer_pay_type', 'string'),
#  ('secondary_payer_plan_type', 'string'),
#  ('secondary_payer_state', 'string'),
#  ('source_id', 'string'),
#  ('source_increment_id', 'string'),
#  ('type_of_bill_classification_description', 'string'),
#  ('type_of_bill_code', 'string'),
#  ('type_of_bill_facility_description', 'string'),
#  ('type_of_bill_frequency_description', 'string'),
#  ('vendorname', 'string'),
#  ('line_level_number', 'string'),
#  ('line_level_emergency_indicator', 'string'),
#  ('line_level_charge_amount', 'string'),
#  ('line_level_drug_ndc', 'string'),
#  ('line_level_drug_dosage_route', 'string'),
#  ('line_level_drug_name', 'string'),
#  ('line_level_drug_packaging_information', 'string'),
#  ('line_level_drug_product_type', 'string'),
#  ('line_level_drug_brand_name', 'string'),
#  ('line_level_place_of_service_description', 'string'),
#  ('line_level_place_of_service_code', 'string'),
#  ('line_level_procedure_code', 'string'),
#  ('line_level_procedure_code_set', 'string'),
#  ('line_level_procedure_description', 'string'),
#  ('line_level_procedure_modifier_1', 'string'),
#  ('line_level_procedure_modifier_2', 'string'),
#  ('line_level_procedure_modifier_3', 'string'),
#  ('line_level_procedure_modifier_4', 'string'),
#  ('line_level_procedure_category', 'string'),
#  ('line_level_revenue_code', 'string'),
#  ('line_level_revenue_description', 'string'),
#  ('line_level_from_date', 'date'),
#  ('line_level_to_date', 'date'),
#  ('line_level_units_billed', 'string')]

# %%
null_counts_all_columns = df1.select([count(when(col(c).isNull(), c)).alias(c) for c in df1.columns])

null_counts_all_columns.show()
# Out:
# 24/09/23 16:01:57 ERROR Executor: Exception in task 4.0 in stage 198.0 (TID 827)
# java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.lang.invoke.MethodTypeForm.setCachedLambdaForm(MethodTypeForm.java:144)
# 	at java.base/java.lang.invoke.Invokers.callSiteForm(Invokers.java:608)
# 	at java.base/java.lang.invoke.Invokers.linkToTargetMethod(Invokers.java:572)
# 	at java.base/java.lang.invoke.MethodHandleNatives.linkCallSiteImpl(MethodHandleNatives.java:288)
# 	at java.base/java.lang.invoke.MethodHandleNatives.linkCallSite(MethodHandleNatives.java:265)
# 	at org.apache.spark.sql.execution.aggregate.AggregationIterator.initializeAggregateFunctions(AggregationIterator.scala:81)
# 	at org.apache.spark.sql.execution.aggregate.AggregationIterator.<init>(AggregationIterator.scala:118)
# 	at org.apache.spark.sql.execution.aggregate.TungstenAggregationIterator.<init>(TungstenAggregationIterator.scala:106)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1(HashAggregateExec.scala:123)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1$adapted(HashAggregateExec.scala:97)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec$$Lambda/0x0000000127119d58.apply(Unknown Source)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2$adapted(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD$$Lambda/0x0000000126fc4000.apply(Unknown Source)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.executor.Executor$TaskRunner$$Lambda/0x0000000126906908.apply(Unknown Source)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 24/09/23 16:01:57 ERROR Executor: Exception in task 3.0 in stage 198.0 (TID 826)
# java.lang.OutOfMemoryError: Java heap space
# 	at org.apache.parquet.bytes.BytesInput$StreamBytesInput.toByteArray(BytesInput.java:285)
# 	at org.apache.parquet.bytes.BytesInput.toByteBuffer(BytesInput.java:237)
# 	at org.apache.parquet.bytes.BytesInput.toInputStream(BytesInput.java:246)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPageV1(VectorizedColumnReader.java:367)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.access$000(VectorizedColumnReader.java:49)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:272)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:268)
# 	at org.apache.parquet.column.page.DataPageV1.accept(DataPageV1.java:120)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPage(VectorizedColumnReader.java:268)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readBatch(VectorizedColumnReader.java:186)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:342)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:236)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:283)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1(HashAggregateExec.scala:100)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1$adapted(HashAggregateExec.scala:97)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec$$Lambda/0x0000000127119d58.apply(Unknown Source)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2$adapted(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD$$Lambda/0x0000000126fc4000.apply(Unknown Source)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 24/09/23 16:01:57 ERROR Executor: Exception in task 1.0 in stage 198.0 (TID 824)
# java.lang.OutOfMemoryError: Java heap space
# 	at org.apache.parquet.bytes.BytesInput$StreamBytesInput.toByteArray(BytesInput.java:285)
# 	at org.apache.parquet.bytes.BytesInput.toByteBuffer(BytesInput.java:237)
# 	at org.apache.parquet.bytes.BytesInput.toInputStream(BytesInput.java:246)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPageV1(VectorizedColumnReader.java:367)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.access$000(VectorizedColumnReader.java:49)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:272)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:268)
# 	at org.apache.parquet.column.page.DataPageV1.accept(DataPageV1.java:120)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPage(VectorizedColumnReader.java:268)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readBatch(VectorizedColumnReader.java:186)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:342)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:236)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:283)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1(HashAggregateExec.scala:100)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1$adapted(HashAggregateExec.scala:97)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec$$Lambda/0x0000000127119d58.apply(Unknown Source)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2$adapted(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD$$Lambda/0x0000000126fc4000.apply(Unknown Source)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 24/09/23 16:01:57 ERROR Executor: Exception in task 6.0 in stage 198.0 (TID 829)
# java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.nio.HeapByteBuffer.duplicate(HeapByteBuffer.java:138)
# 	at org.apache.parquet.bytes.SingleBufferInputStream.slice(SingleBufferInputStream.java:120)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedRleValuesReader.readNextGroup(VectorizedRleValuesReader.java:935)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedRleValuesReader.readBatchInternal(VectorizedRleValuesReader.java:213)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedRleValuesReader.readIntegers(VectorizedRleValuesReader.java:193)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readBatch(VectorizedColumnReader.java:204)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:342)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:236)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:283)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1(HashAggregateExec.scala:100)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1$adapted(HashAggregateExec.scala:97)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec$$Lambda/0x0000000127119d58.apply(Unknown Source)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2$adapted(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD$$Lambda/0x0000000126fc4000.apply(Unknown Source)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.executor.Executor$TaskRunner$$Lambda/0x0000000126906908.apply(Unknown Source)
# 24/09/23 16:01:57 ERROR SparkUncaughtExceptionHandler: Uncaught exception in thread Thread[#856,Executor task launch worker for task 3.0 in stage 198.0 (TID 826),5,main]
# java.lang.OutOfMemoryError: Java heap space
# 	at org.apache.parquet.bytes.BytesInput$StreamBytesInput.toByteArray(BytesInput.java:285)
# 	at org.apache.parquet.bytes.BytesInput.toByteBuffer(BytesInput.java:237)
# 	at org.apache.parquet.bytes.BytesInput.toInputStream(BytesInput.java:246)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPageV1(VectorizedColumnReader.java:367)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.access$000(VectorizedColumnReader.java:49)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:272)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:268)
# 	at org.apache.parquet.column.page.DataPageV1.accept(DataPageV1.java:120)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPage(VectorizedColumnReader.java:268)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readBatch(VectorizedColumnReader.java:186)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:342)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:236)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:283)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1(HashAggregateExec.scala:100)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1$adapted(HashAggregateExec.scala:97)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec$$Lambda/0x0000000127119d58.apply(Unknown Source)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2$adapted(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD$$Lambda/0x0000000126fc4000.apply(Unknown Source)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 24/09/23 16:01:57 ERROR SparkUncaughtExceptionHandler: Uncaught exception in thread Thread[#854,Executor task launch worker for task 1.0 in stage 198.0 (TID 824),5,main]
# java.lang.OutOfMemoryError: Java heap space
# 	at org.apache.parquet.bytes.BytesInput$StreamBytesInput.toByteArray(BytesInput.java:285)
# 	at org.apache.parquet.bytes.BytesInput.toByteBuffer(BytesInput.java:237)
# 	at org.apache.parquet.bytes.BytesInput.toInputStream(BytesInput.java:246)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPageV1(VectorizedColumnReader.java:367)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.access$000(VectorizedColumnReader.java:49)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:272)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader$1.visit(VectorizedColumnReader.java:268)
# 	at org.apache.parquet.column.page.DataPageV1.accept(DataPageV1.java:120)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readPage(VectorizedColumnReader.java:268)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readBatch(VectorizedColumnReader.java:186)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:342)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:236)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:283)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1(HashAggregateExec.scala:100)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1$adapted(HashAggregateExec.scala:97)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec$$Lambda/0x0000000127119d58.apply(Unknown Source)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2$adapted(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD$$Lambda/0x0000000126fc4000.apply(Unknown Source)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 24/09/23 16:01:57 ERROR SparkUncaughtExceptionHandler: Uncaught exception in thread Thread[#857,Executor task launch worker for task 4.0 in stage 198.0 (TID 827),5,main]
# java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.lang.invoke.MethodTypeForm.setCachedLambdaForm(MethodTypeForm.java:144)
# 	at java.base/java.lang.invoke.Invokers.callSiteForm(Invokers.java:608)
# 	at java.base/java.lang.invoke.Invokers.linkToTargetMethod(Invokers.java:572)
# 	at java.base/java.lang.invoke.MethodHandleNatives.linkCallSiteImpl(MethodHandleNatives.java:288)
# 	at java.base/java.lang.invoke.MethodHandleNatives.linkCallSite(MethodHandleNatives.java:265)
# 	at org.apache.spark.sql.execution.aggregate.AggregationIterator.initializeAggregateFunctions(AggregationIterator.scala:81)
# 	at org.apache.spark.sql.execution.aggregate.AggregationIterator.<init>(AggregationIterator.scala:118)
# 	at org.apache.spark.sql.execution.aggregate.TungstenAggregationIterator.<init>(TungstenAggregationIterator.scala:106)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1(HashAggregateExec.scala:123)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1$adapted(HashAggregateExec.scala:97)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec$$Lambda/0x0000000127119d58.apply(Unknown Source)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2$adapted(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD$$Lambda/0x0000000126fc4000.apply(Unknown Source)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.executor.Executor$TaskRunner$$Lambda/0x0000000126906908.apply(Unknown Source)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 24/09/23 16:01:57 ERROR SparkUncaughtExceptionHandler: Uncaught exception in thread Thread[#859,Executor task launch worker for task 6.0 in stage 198.0 (TID 829),5,main]
# java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.nio.HeapByteBuffer.duplicate(HeapByteBuffer.java:138)
# 	at org.apache.parquet.bytes.SingleBufferInputStream.slice(SingleBufferInputStream.java:120)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedRleValuesReader.readNextGroup(VectorizedRleValuesReader.java:935)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedRleValuesReader.readBatchInternal(VectorizedRleValuesReader.java:213)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedRleValuesReader.readIntegers(VectorizedRleValuesReader.java:193)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readBatch(VectorizedColumnReader.java:204)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:342)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:236)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:283)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1(HashAggregateExec.scala:100)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1$adapted(HashAggregateExec.scala:97)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec$$Lambda/0x0000000127119d58.apply(Unknown Source)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2$adapted(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD$$Lambda/0x0000000126fc4000.apply(Unknown Source)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.executor.Executor$TaskRunner$$Lambda/0x0000000126906908.apply(Unknown Source)
# 24/09/23 16:01:57 WARN TaskSetManager: Lost task 6.0 in stage 198.0 (TID 829) (10.50.78.245 executor driver): java.lang.OutOfMemoryError: Java heap space
# 	at java.base/java.nio.HeapByteBuffer.duplicate(HeapByteBuffer.java:138)
# 	at org.apache.parquet.bytes.SingleBufferInputStream.slice(SingleBufferInputStream.java:120)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedRleValuesReader.readNextGroup(VectorizedRleValuesReader.java:935)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedRleValuesReader.readBatchInternal(VectorizedRleValuesReader.java:213)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedRleValuesReader.readIntegers(VectorizedRleValuesReader.java:193)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedColumnReader.readBatch(VectorizedColumnReader.java:204)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextBatch(VectorizedParquetRecordReader.java:342)
# 	at org.apache.spark.sql.execution.datasources.parquet.VectorizedParquetRecordReader.nextKeyValue(VectorizedParquetRecordReader.java:236)
# 	at org.apache.spark.sql.execution.datasources.RecordReaderIterator.hasNext(RecordReaderIterator.scala:39)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.nextIterator(FileScanRDD.scala:283)
# 	at org.apache.spark.sql.execution.datasources.FileScanRDD$$anon$1.hasNext(FileScanRDD.scala:129)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1(HashAggregateExec.scala:100)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec.$anonfun$doExecute$1$adapted(HashAggregateExec.scala:97)
# 	at org.apache.spark.sql.execution.aggregate.HashAggregateExec$$Lambda/0x0000000127119d58.apply(Unknown Source)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD.$anonfun$mapPartitionsWithIndex$2$adapted(RDD.scala:910)
# 	at org.apache.spark.rdd.RDD$$Lambda/0x0000000126fc4000.apply(Unknown Source)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:104)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.executor.Executor$TaskRunner$$Lambda/0x0000000126906908.apply(Unknown Source)
#
# 24/09/23 16:01:57 ERROR TaskSetManager: Task 6 in stage 198.0 failed 1 times; aborting job
# 24/09/23 16:01:58 ERROR Utils: Uncaught exception in thread Executor task launch worker for task 7.0 in stage 198.0 (TID 830)
# java.lang.NullPointerException: Cannot invoke "org.apache.spark.SparkEnv.blockManager()" because the return value of "org.apache.spark.SparkEnv$.get()" is null
# 	at org.apache.spark.scheduler.Task.$anonfun$run$3(Task.scala:146)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:144)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1570)
# 24/09/23 16:01:58 ERROR Utils: Uncaught exception in thread Executor task launch worker for task 5.0 in stage 198.0 (TID 828)
# java.lang.NullPointerException: Cannot invoke "org.apache.spark.SparkEnv.blockManager()" because the return value of "org.apache.spark.SparkEnv$.get()" is null
# 	at org.apache.spark.scheduler.Task.$anonfun$run$3(Task.scala:146)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:144)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1570)
# 24/09/23 16:01:58 ERROR Utils: Uncaught exception in thread Executor task launch worker for task 2.0 in stage 198.0 (TID 825)
# java.lang.NullPointerException: Cannot invoke "org.apache.spark.SparkEnv.blockManager()" because the return value of "org.apache.spark.SparkEnv$.get()" is null
# 	at org.apache.spark.scheduler.Task.$anonfun$run$3(Task.scala:146)
# 	at org.apache.spark.util.Utils$.tryLogNonFatalError(Utils.scala:1375)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:144)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.lang.Thread.run(Thread.java:1570)
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py", line 179, in deco
#     return f(*a, **kw)
#            ^^^^^^^^^^^
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/protocol.py", line 326, in get_return_value
#     raise Py4JJavaError(
# py4j.protocol.Py4JJavaError: <exception str() failed>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 52691)
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socketserver.py", line 318, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/local/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socketserver.py", line 349, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/local/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/local/Cellar/python@3.12/3.12.5/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socketserver.py", line 761, in __init__
#     self.handle()
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 295, in handle
#     poll(accum_updates)
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 267, in poll
#     if self.rfile in r and func():
#                            ^^^^^^
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/accumulators.py", line 271, in accum_updates
#     num_updates = read_int(self.rfile)
#                   ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/serializers.py", line 596, in read_int
#     raise EOFError
# EOFError
# ----------------------------------------
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# File ~/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py:179, in capture_sql_exception.<locals>.deco(*a, **kw)
#     178 try:
# --> 179     return f(*a, **kw)
#     180 except Py4JJavaError as e:
#
# File ~/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#
# <class 'str'>: (<class 'ConnectionRefusedError'>, ConnectionRefusedError(61, 'Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Py4JError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       2 null_counts_all_columns = df1.select([count(when(col(c).isNull(), c)).alias(c) for c in df1.columns])
#       4 # Show the null counts
# ----> 5 null_counts_all_columns.show()
#
# File ~/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/sql/dataframe.py:947, in DataFrame.show(self, n, truncate, vertical)
#     887 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
#     888     """Prints the first ``n`` rows to the console.
#     889
#     890     .. versionadded:: 1.3.0
#    (...)
#     945     name | Bob
#     946     """
# --> 947     print(self._show_string(n, truncate, vertical))
#
# File ~/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/sql/dataframe.py:965, in DataFrame._show_string(self, n, truncate, vertical)
#     959     raise PySparkTypeError(
#     960         error_class="NOT_BOOL",
#     961         message_parameters={"arg_name": "vertical", "arg_type": type(vertical).__name__},
#     962     )
#     964 if isinstance(truncate, bool) and truncate:
# --> 965     return self._jdf.showString(n, 20, vertical)
#     966 else:
#     967     try:
#
# File ~/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py:181, in capture_sql_exception.<locals>.deco(*a, **kw)
#     179     return f(*a, **kw)
#     180 except Py4JJavaError as e:
# --> 181     converted = convert_exception(e.java_exception)
#     182     if not isinstance(converted, UnknownException):
#     183         # Hide where the exception came from that shows a non-Pythonic
#     184         # JVM exception message.
#     185         raise converted from None
#
# File ~/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py:173, in convert_exception(e)
#     167     msg = (
#     168         "\n  An exception was thrown from the Python worker. "
#     169         "Please see the stack trace below.\n%s" % c.getMessage()
#     170     )
#     171     return PythonException(msg, stacktrace)
# --> 173 return UnknownException(desc=e.toString(), stackTrace=stacktrace, cause=c)
#
# File ~/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py:65, in CapturedException.__init__(self, desc, stackTrace, cause, origin)
#      59 assert SparkContext._jvm is not None
#      60 self.stackTrace = (
#      61     stackTrace
#      62     if stackTrace is not None
#      63     else (SparkContext._jvm.org.apache.spark.util.Utils.exceptionString(origin))
#      64 )
# ---> 65 self.cause = convert_exception(cause) if cause is not None else None
#      66 if self.cause is None and origin is not None and origin.getCause() is not None:
#      67     self.cause = convert_exception(origin.getCause())
#
# File ~/coding/doctor-right/.venv/lib/python3.12/site-packages/pyspark/errors/exceptions/captured.py:141, in convert_exception(e)
#     139 elif is_instance_of(gw, e, "java.lang.NumberFormatException"):
#     140     return NumberFormatException(origin=e)
# --> 141 elif is_instance_of(gw, e, "java.lang.IllegalArgumentException"):
#     142     return IllegalArgumentException(origin=e)
#     143 elif is_instance_of(gw, e, "java.lang.ArithmeticException"):
#
# File ~/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/java_gateway.py:464, in is_instance_of(gateway, java_object, java_class)
#     460 else:
#     461     raise Py4JError(
#     462         "java_class must be a string, a JavaClass, or a JavaObject")
# --> 464 return gateway.jvm.py4j.reflection.TypeUtil.isInstanceOf(
#     465     param, java_object)
#
# File ~/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/java_gateway.py:1725, in JVMView.__getattr__(self, name)
#    1722 _, error_message = get_error_message(answer)
#    1723 message = compute_exception_message(
#    1724     "{0} does not exist in the JVM".format(name), error_message)
# -> 1725 raise Py4JError(message)
#
# Py4JError: py4j does not exist in the JVM
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/sahil/coding/doctor-right/.venv/lib/python3.12/site-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
